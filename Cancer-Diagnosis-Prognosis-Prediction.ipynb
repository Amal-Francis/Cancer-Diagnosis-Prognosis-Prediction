# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
name=['Id', 'Outcome', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
         'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean',
          'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se',
          'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se',
          'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst',
          'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
           'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

diagnostic = pd.read_csv('Breast Cancer Wisconsin (Diagnostic) -wbc.csv', names=name)
prognostic = pd.read_csv('prognostic-wbc.csv')

# %%
diagnostic.head()
# Out:
#          Id Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302       M        17.99         10.38          122.80     1001.0
# 1    842517       M        20.57         17.77          132.90     1326.0
# 2  84300903       M        19.69         21.25          130.00     1203.0
# 3  84348301       M        11.42         20.38           77.58      386.1
# 4  84358402       M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
prognostic.head()
# Out:
#    119513  N   31  18.02   27.6   117.5    1013  0.09489  0.1036  0.1086  ...  \
# 0    8423  N   61  17.99  10.38  122.80  1001.0  0.11840  0.2776  0.3001  ...
# 1  842517  N  116  21.37  17.44  137.50  1373.0  0.08836  0.1189  0.1255  ...
# 2  843483  N  123  11.42  20.38   77.58   386.1  0.14250  0.2839  0.2414  ...
# 3  843584  R   27  20.29  14.34  135.10  1297.0  0.10030  0.1328  0.1980  ...
# 4  843786  R   77  12.75  15.29   84.60   502.7  0.11890  0.1569  0.1664  ...
#
#     139.7    1436  0.1195  0.1926   0.314   0.117  0.2677  0.08113    5  5.1
# 0  184.60  2019.0  0.1622  0.6656  0.7119  0.2654  0.4601  0.11890  3.0    2
# 1  159.10  1949.0  0.1188  0.3449  0.3414  0.2032  0.4334  0.09067  2.5    0
# 2   98.87   567.7  0.2098  0.8663  0.6869  0.2575  0.6638  0.17300  2.0    0
# 3  152.20  1575.0  0.1374  0.2050  0.4000  0.1625  0.2364  0.07678  3.5    0
# 4  107.30   733.2  0.1706  0.4196  0.5999  0.1709  0.3485  0.11790  2.5    0
#
# [5 rows x 35 columns]

# %%
prognostic.drop(prognostic.columns[2], axis=1, inplace=True)
prognostic.drop(prognostic.columns[-1], axis=1, inplace=True)
prognostic.drop(prognostic.columns[-1], axis=1, inplace=True)

# %%
prognostic.shape
# Out:
# (197, 32)

# %%
diagnostic.shape
# Out:
# (569, 32)

# %%
prognostic.columns = name

# %%
prognostic.head()
# Out:
#        Id Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    8423       N        17.99         10.38          122.80     1001.0
# 1  842517       N        21.37         17.44          137.50     1373.0
# 2  843483       N        11.42         20.38           77.58      386.1
# 3  843584       R        20.29         14.34          135.10     1297.0
# 4  843786       R        12.75         15.29           84.60      502.7
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840            0.2776          0.3001              0.14710
# 1          0.08836            0.1189          0.1255              0.08180
# 2          0.14250            0.2839          0.2414              0.10520
# 3          0.10030            0.1328          0.1980              0.10430
# 4          0.11890            0.1569          0.1664              0.07666
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# ### EDA

# %%
print("Number of instances",prognostic.shape[0])
print("\nNumber of attributes",prognostic.shape[1])
print("\nNumber of unique values\n",prognostic.nunique())
print("\nNumber of null values\n",prognostic.isnull().sum())
print("\nNumber of predicted values\n",prognostic['Outcome'].value_counts())
# Out:
# Number of instances 197
#
# Number of attributes 32
#
# Number of unique values
#  Id                         197
# Outcome                      2
# radius_mean                176
# texture_mean               192
# perimeter_mean             181
# area_mean                  191
# smoothness_mean            178
# compactness_mean           191
# concavity_mean             195
# concave points_mean        188
# symmetry_mean              174
# fractal_dimension_mean     193
# radius_se                  195
# texture_se                 190
# perimeter_se               191
# area_se                    195
# smoothness_se              195
# compactness_se             192
# concavity_se               191
# concave points_se          186
# symmetry_se                188
# fractal_dimension_se       194
# radius_worst               181
# texture_worst              186
# perimeter_worst            182
# area_worst                 191
# smoothness_worst           171
# ...

# %%
print("Number of instances",diagnostic.shape[0])
print("\nNumber of attributes",diagnostic.shape[1])
print("\nNumber of unique values\n",diagnostic.nunique())
print("\nNumber of null values\n",diagnostic.isnull().sum())
print("\nNumber of predicted values\n",diagnostic['Outcome'].value_counts())
# Out:
# Number of instances 569
#
# Number of attributes 32
#
# Number of unique values
#  Id                         569
# Outcome                      2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# ...

# %%
diagnostic.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
prognostic.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.970000e+02   197.000000    197.000000      197.000000   197.000000
# mean   1.999966e+06    17.409239     22.248985      114.843147   969.822843
# std    2.893285e+06     3.169432      4.292343       21.437046   353.033009
# min    8.423000e+03    10.950000     10.380000       71.900000   361.600000
# 25%    8.561060e+05    15.050000     19.380000       98.000000   701.900000
# 50%    8.864520e+05    17.290000     21.720000      113.400000   928.800000
# 75%    9.279970e+05    19.590000     24.520000      129.700000  1194.000000
# max    9.411300e+06    27.220000     39.280000      182.100000  2250.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       197.000000        197.000000      197.000000           197.000000
# mean          0.102721          0.142846        0.156485             0.086858
# ...

# %%
len(diagnostic)
# Out:
# 569

# %%
diagnostic['Data'] = 'diagnostic'
prognostic['Data'] = 'prognostic'
B_can = pd.concat([diagnostic, prognostic], ignore_index=True)
B_can
# Out:
#            Id Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302       M        17.99         10.38          122.80     1001.0
# 1      842517       M        20.57         17.77          132.90     1326.0
# 2    84300903       M        19.69         21.25          130.00     1203.0
# 3    84348301       M        11.42         20.38           77.58      386.1
# 4    84358402       M        20.29         14.34          135.10     1297.0
# ..        ...     ...          ...           ...             ...        ...
# 761    942640       N        22.52         21.92          146.90     1597.0
# 762    943471       N        15.44         31.18          101.00      740.4
# 763     94547       N        17.17         29.19          110.00      915.3
# 764    947204       R        21.42         22.84          145.00     1440.0
# 765    947489       N        16.70         28.13          110.30      885.4
#
# ...

# %%
print("Number of instances",B_can.shape[0])
print("\nNumber of attributes",B_can.shape[1])
print("\nNumber of unique values\n",B_can.nunique())
print("\nNumber of null values\n",B_can.isnull().sum())
print("\nNumber of predicted values\n",B_can['Outcome'].value_counts())
# Out:
# Number of instances 766
#
# Number of attributes 33
#
# Number of unique values
#  Id                         627
# Outcome                      4
# radius_mean                482
# texture_mean               517
# perimeter_mean             552
# area_mean                  577
# smoothness_mean            502
# compactness_mean           568
# concavity_mean             576
# concave points_mean        573
# symmetry_mean              450
# fractal_dimension_mean     525
# radius_se                  579
# texture_se                 556
# perimeter_se               571
# area_se                    565
# smoothness_se              584
# compactness_se             575
# concavity_se               573
# concave points_se          538
# symmetry_se                529
# fractal_dimension_se       582
# radius_worst               487
# texture_worst              540
# perimeter_worst            544
# area_worst                 580
# smoothness_worst           427
# ...

# %%
B_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       766 non-null    int64
#  1   Outcome                  766 non-null    object
#  2   radius_mean              766 non-null    float64
#  3   texture_mean             766 non-null    float64
#  4   perimeter_mean           766 non-null    float64
#  5   area_mean                766 non-null    float64
#  6   smoothness_mean          766 non-null    float64
#  7   compactness_mean         766 non-null    float64
#  8   concavity_mean           766 non-null    float64
#  9   concave points_mean      766 non-null    float64
#  10  symmetry_mean            766 non-null    float64
#  11  fractal_dimension_mean   766 non-null    float64
#  12  radius_se                766 non-null    float64
#  13  texture_se               766 non-null    float64
# ...

# %%
B_can.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  7.660000e+02   766.000000    766.000000      766.000000   766.000000
# mean   2.307515e+07    14.971343     20.050731       97.851802   735.883812
# std    1.084493e+08     3.722223      4.486739       25.616779   377.963417
# min    8.423000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.652085e+05    12.210000     16.932500       78.295000   459.100000
# 50%    9.029935e+05    14.250000     19.660000       93.615000   632.500000
# 75%    8.711152e+06    17.600000     22.485000      115.200000   969.300000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       766.000000        766.000000      766.000000           766.000000
# mean          0.097996          0.114244        0.106207             0.058676
# ...

# %% [markdown]
# ### 2. Required plottings

# %%
sns.countplot(x='Outcome', data=diagnostic)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x='Outcome', data=prognostic)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x='Outcome', data=B_can)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x='Outcome' , data=B_can, hue='Data')
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %% [markdown]
# ### 3. Nan Values plotting

# %%
sns.set()
sns.barplot(x=B_can.isnull().sum().index, y=B_can.isnull().sum().values)
plt.ylabel('Nan Count')
plt.xlabel('Column Name')
plt.xticks(rotation=90, color='darkblue'       )
plt.show()

# %% [markdown]
# ## Taking the data as y

# %% [markdown]
# ### 5. Train test

# %%
from sklearn.model_selection import train_test_split
x = B_can.drop(['Id','Data'],axis =1 )
y = B_can.Data

# %%
from sklearn.preprocessing import LabelEncoder
x['Outcome'] = LabelEncoder().fit_transform(x['Outcome'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 6. Finding Feature importance and also plotting

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=70).fit(x_train, y_train)

# %%
rf.score(x_test, y_test)
# Out:
# 0.9935064935064936

# %%
y_predict = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_predict, y_test)
# Out:
# 0.9935064935064936

# %%
f =pd.Series( rf.feature_importances_, index=x_train.columns)

# %%
f.nlargest(20).plot(kind='barh')
plt.title('Feature importance',size=20, weight='bold', color='darkblue')
plt.show()

# %%
x.columns
# Out:
# Index(['Outcome', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x_new = x.drop(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
       'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se','texture_worst',
        'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 
       'symmetry_worst', 'fractal_dimension_worst',  ], axis=1)

# %% [markdown]
# ### 7. Use compare ml algorithms to find accuracy

# %%
from  sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import warnings
warnings.filterwarnings('ignore')

# %%
models = []
models.append(('LB' , LogisticRegression(max_iter=1000)))
models.append(('LDA' , LinearDiscriminantAnalysis()))
models.append(('DT' , DecisionTreeClassifier()))
models.append(('NB' , GaussianNB()))
models.append(('SVM' , SVC(max_iter=10000)))

# %%
result = []
names = []
for  name, model in models:
    cv = cross_val_score(model, x_new, y, cv=KFold(n_splits=10), scoring='accuracy')
    result.append(cv)
    names.append(name)
    print(name +':',cv.mean(), cv.std() )
# Out:
# LB: 1.0 0.0
# LDA: 0.994736842105263 0.010526315789473672
# DT: 1.0 0.0
# NB: 0.9674641148325358 0.022641954371017126
# SVM: 0.6680622009569378 0.3759938230223276

# %%
# plot
ax =plt.subplot(111)
ax.boxplot(result)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# # OR

# %% [markdown]
# ## Taking the Outcome as y

# %% [markdown]
# ### 5. Train test

# %%
from sklearn.model_selection import train_test_split
x = B_can.drop(['Id','Data', 'Outcome'],axis =1 )
y = B_can.Outcome

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 6. Finding Feature importance and also plotting

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier().fit(x_train, y_train)

# %%
rf.score(x_test, y_test)
# Out:
# 0.577922077922078

# %%
y_predict = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_predict, y_test)
# Out:
# 0.577922077922078

# %%
f =pd.Series( rf.feature_importances_, index=x_train.columns)

# %%
f.nlargest(20).plot(kind='barh')
plt.title('Feature importance',size=25, weight='bold', color='darkblue')
plt.show()

# %%
x.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x_new= x.drop(['radius_mean', 'texture_mean', 'perimeter_mean',
       'smoothness_mean', 'compactness_mean', 
        'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'texture_worst',
         'smoothness_worst',
       'compactness_worst', 'concavity_worst',
       'symmetry_worst', 'fractal_dimension_worst'], axis=1)

# %% [markdown]
# ### 7. Use compare ml algorithms to find accuracy

# %%
from  sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import warnings
warnings.filterwarnings('ignore')

# %%
models = []
models.append(('LB' , LogisticRegression(max_iter=1000)))
models.append(('LDA' , LinearDiscriminantAnalysis()))
models.append(('DT' , DecisionTreeClassifier()))
models.append(('NB' , GaussianNB()))
models.append(('SVM' , SVC(max_iter=10000)))

# %%
result = []
names = []
for  name, model in models:
    cv = cross_val_score(model, x_new, y, cv=KFold(n_splits=10), scoring='accuracy')
    result.append(cv)
    names.append(name)
    print(name +':',cv.mean(), cv.std() )
# Out:
# LB: 0.6471462747778537 0.3704464927448714
# LDA: 0.6134825700615173 0.3489000317421741
# DT: 0.47535885167464115 0.27685304060160093
# NB: 0.5747778537252222 0.24687286102108155
# SVM: 0.6640635680109364 0.3736000983732515

# %%
# plot
ax =plt.subplot(111)
ax.boxplot(result)
ax.set_xticklabels(names)
plt.show()
